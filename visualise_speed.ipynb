# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from PIL import Image

# %%
csv_path = "/mnt/c/Users/psamt/OneDrive - The University of Nottingham/_Spring/PHYS4036_Machine Learning in Science Part II/Project/Dataset/machine-learning-in-science-ii-2025/training_norm.csv"

image_dir = "/mnt/c/Users/psamt/OneDrive - The University of Nottingham/_Spring/PHYS4036_Machine Learning in Science Part II/Project/Dataset/machine-learning-in-science-ii-2025/training_data/training_data"

# %%
df = pd.read_csv(csv_path).set_index('image_id')
ii = 0
step = 200

# %%
temp = df[ii:ii+step]
image_id_list = temp[temp['speed']==0].index.to_list()

fig, ax = plt.subplots(10, 10, figsize=(20, 15))

ax = ax.ravel()

for i in range(len(ax)):
  image = Image.open(image_dir + "/" + str(image_id_list[i]) + ".png")
  ax[i].imshow(image)
print(ii)
ii+=step
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 9
#       6 ax = ax.ravel()
#       8 for i in range(len(ax)):
# ----> 9   image = Image.open(image_dir + "/" + str(image_id_list[i]) + ".png")
#      10   ax[i].imshow(image)
#      11 print(ii)
#
# IndexError: list index out of range
